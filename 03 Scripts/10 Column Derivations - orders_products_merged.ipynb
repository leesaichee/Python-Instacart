# %% [markdown]
# # Table of Content
# 01. Import Libraries
# 02. Import Data
# 03. Derive New Columns
# - 3.1 price_range
# - 3.2 busiest_day
# - 3.3 busiest_days
# - 3.4 busiest_period_of_day
# - 3.5 max_order
# - 3.6 loyalty_flag
# - 3.7 avg_price
# - 3.8 spender_flag
# - 3.9 median_order_interval
# - 3.10 order_frequency_flag
# 04. Export Data

# %% [markdown]
# # 01. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
# Define the main project folder path
path = r'C:\Users\saich\Desktop\CareerFoundry\Data Immersion\Achievement 4 Python Fundamentals for Data Analysts\04-2023 Instacart Basket Analysis (github)'

# %%
# Import 'orders_products_merged' data set from 'Prepared Data' folder
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge
# 0         Soda        77              7     9.0   both
# 1         Soda        77              7     9.0   both
# 2         Soda        77              7     9.0   both
# 3         Soda        77              7     9.0   both
# 4         Soda        77              7     9.0   both

# %%
ords_prods_merged.shape
# Out:
# (32399732, 14)

# %% [markdown]
# # 03. Derive New Columns

# %% [markdown]
# ### 03.1 price_range

# %%
# Create a new column 'price_range' based on the 'prices' value
ords_prods_merged.loc[ords_prods_merged['prices'] <= 5, 'price_range'] = 'Low-range product'

# %%
ords_prods_merged.loc[(ords_prods_merged['prices'] > 5) & (ords_prods_merged['prices'] <= 15), 'price_range'] = 'Mid-range product'

# %%
ords_prods_merged.loc[ords_prods_merged['prices'] > 15, 'price_range'] = 'High-range product'

# %%
# Check the output
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product

# %%
ords_prods_merged['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      412551
# Name: price_range, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 15)

# %% [markdown]
# ### 03.2 busiest_day

# %%
# First, check the frequency of 'order_day_of_week'
ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6203329
# 1    5659298
# 6    4495887
# 2    4213105
# 5    4205076
# 3    3839865
# 4    3783172
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# 0 (Sat) has the most counts, it is the busiest day. 4 (Wed) has the least count, it is the least busy day.
# Note: 0 (Sat), 1 (Sun), 2 (Mon), 3 (Tue), 4 (Wed), 5 (Thu), 6 (Fri)

# %%
# Create a list 'result_busiest_day' that will contain 'Most busy', 'Regular busy' and 'Least busy' using if-statements with for loop
result_busiest_day = []

for x in ords_prods_merged['order_day_of_week']: 
    if (x == 0): 
        result_busiest_day.append('Most busy')
    elif (x == 4): 
        result_busiest_day.append('Least busy')
    else: 
        result_busiest_day.append('Regular busy')

# %%
# Create a new column 'busiest_day' and set it equal to 'result_busiest_day'
ords_prods_merged['busiest_day'] = result_busiest_day

# %%
# Check for output
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#     busiest_day
# 0  Regular busy
# 1  Regular busy
# 2  Regular busy
# 3    Least busy
# 4    Least busy

# %%
ords_prods_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regular busy    22413231
# Most busy        6203329
# Least busy       3783172
# Name: busiest_day, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 16)

# %% [markdown]
# ### 03.3 busiest_days

# %%
# First, check the frequency of 'order_day_of_week'
ords_prods_merged['order_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6203329
# 1    5659298
# 6    4495887
# 2    4213105
# 5    4205076
# 3    3839865
# 4    3783172
# Name: order_day_of_week, dtype: int64

# %% [markdown]
# 0 (Sat) and 1 (Sun) have the most counts, they are the busiest days. 3 (Tue) and 4 (Wed) have the least counts, they are the least busy days.
# Note: 0 (Sat), 1 (Sun), 2 (Mon), 3 (Tue), 4 (Wed), 5 (Thu), 6 (Fri)

# %%
# Create a list 'result_busiest_days' that will contain 'Most busy', 'Regular busy' and 'Least busy' using if-statements with for loop
result_busiest_days = []

for x in ords_prods_merged['order_day_of_week']: 
    if (x == 0) or (x == 1): 
        result_busiest_days.append('Most busy')
    elif (x == 3) or (x == 4): 
        result_busiest_days.append('Least busy')
    else: 
        result_busiest_days.append('Regular busy')

# %%
# Create a new column 'busiest_days' and set it equal to 'result_busiest_days'
ords_prods_merged['busiest_days'] = result_busiest_days

# %%
# Check for output
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#     busiest_day  busiest_days
# 0  Regular busy  Regular busy
# 1  Regular busy    Least busy
# 2  Regular busy    Least busy
# 3    Least busy    Least busy
# 4    Least busy    Least busy

# %%
ords_prods_merged['busiest_days'].value_counts(dropna = False)
# Out:
# Regular busy    12914068
# Most busy       11862627
# Least busy       7623037
# Name: busiest_days, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 17)

# %% [markdown]
# ### 03.4 busiest_period_of_day

# %%
# First, check the frequency of 'order_hour_of_day'
ords_prods_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761333
# 11    2735694
# 14    2688728
# 15    2661718
# 13    2660570
# 12    2618104
# 16    2534744
# 9     2453842
# 17    2087273
# 8     1717863
# 18    1636226
# 19    1258076
# 20     976000
# 7      890923
# 21     795528
# 22     634159
# 23     402272
# 6      290450
# 0      218742
# 1      115683
# 5       87944
# 2       69360
# 4       53232
# 3       51268
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# From 0900 to 1700, the number of orders are more than 2 million. These hours are the busiest period of a day, thus they will be labeled as 'Most orders'. From 0700 to 0800, and 1800 to 2200, the number of orders are between 0.5 to 2 million. These hours are the average-busy period of a day, thus they will be labeled as 'Average order'. From 2300 to 0600, the number of orders are less than 0.5 million. These hours are the least busy period of a day, thus they will be labeled as 'Fewest orders'.

# %%
# Create a new column 'busiest_period_of_day' based on the 'order_hour_of_day' value
ords_prods_merged.loc[ords_prods_merged['order_hour_of_day'].isin([9, 10, 11, 12, 13, 14, 15, 16, 17]), 'busiest_period_of_day'] = 'Most orders'

# %%
ords_prods_merged.loc[ords_prods_merged['order_hour_of_day'].isin([7, 8, 18, 19, 20, 21, 22]), 'busiest_period_of_day'] = 'Average orders'

# %%
ords_prods_merged.loc[ords_prods_merged['order_hour_of_day'].isin([23, 0, 1, 2, 3, 4, 5, 6]), 'busiest_period_of_day'] = 'Fewest orders'

# %%
# Check the output
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#     busiest_day  busiest_days busiest_period_of_day
# 0  Regular busy  Regular busy        Average orders
# 1  Regular busy    Least busy        Average orders
# 2  Regular busy    Least busy           Most orders
# 3    Least busy    Least busy        Average orders
# 4    Least busy    Least busy           Most orders

# %%
ords_prods_merged['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       23202006
# Average orders     7908775
# Fewest orders      1288951
# Name: busiest_period_of_day, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 18)

# %% [markdown]
# ### 03.5 max_order

# %%
# Create a new column 'max_order' to store the maximum 'order_number' for each user ID
ords_prods_merged['max_order'] = ords_prods_merged.groupby('user_id')['order_number'].transform(np.max)

# %%
# Check the output
ords_prods_merged.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
# 20   2231262       31            17                  3                 11
# 21   2580647       43             6                  4                 16
# 22   2187180       43             9                  4                 12
# 23   2497897       52             1                  1                  9
# 24   1318871       52             2                  1                 10
# 25   1261384       52             3                  1                 10
# 26    580568       52             5                  2                 10
# 27   2428073       52             7                  2                  7
# 28    342306       52             9                  1                 11
# 29   1520353       52            10                  2                 10
# 30   2542086       52            11                  2                  9
# 31    944694       52            12                  1                 16
# 32   1268191       52            15                  2                 11
# 33   1122089       52            17                  2                 10
# 34   1498922       52            18                  2                 10
# 35    180919       52            19                  3                  8
# 36   2695875       52            21                  5                 10
# 37   3205960       67             1                  3                 11
# 38    970922       67             2                  1                 15
# 39    596585       67             3                  1                 13
# 40   2037087       67             4                  2                  9
# 41   2474111       67             5                  3                 14
# 42   1568481       67             6                  3                 12
# 43   2048527       67             8                  2                 11
# 44   2389031       67             9                  2                 14
# 45   2378562       67            10                  1                 10
# 46   1515698       67            11                  1                 11
# 47   1928050       67            12                  2                 12
# 48   1949274       67            13                  1                 10
# 49    551869       67            14                  1                  9
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
# 25                     7.0         196                  3          1
# 26                     8.0         196                  6          1
# 27                     8.0         196                  5          1
# 28                     7.0         196                  5          1
# 29                     8.0         196                  4          1
# 30                     7.0         196                  3          1
# 31                     6.0         196                  7          1
# 32                     8.0         196                  3          1
# 33                     6.0         196                  4          1
# 34                    14.0         196                  6          1
# 35                     8.0         196                  4          1
# 36                    30.0         196                  1          1
# 37                     NaN         196                  1          0
# 38                     5.0         196                  2          1
# 39                     7.0         196                  2          1
# 40                     8.0         196                  1          1
# 41                     8.0         196                  2          1
# 42                     7.0         196                  2          1
# 43                     7.0         196                  1          1
# 44                     7.0         196                  1          1
# 45                     6.0         196                  1          1
# 46                     7.0         196                  1          1
# 47                     8.0         196                  1          1
# 48                     6.0         196                  1          1
# 49                     7.0         196                  1          1
#
#    product_name  aisle_id  department_id  prices _merge        price_range  \
# 0          Soda        77              7     9.0   both  Mid-range product
# 1          Soda        77              7     9.0   both  Mid-range product
# 2          Soda        77              7     9.0   both  Mid-range product
# 3          Soda        77              7     9.0   both  Mid-range product
# 4          Soda        77              7     9.0   both  Mid-range product
# 5          Soda        77              7     9.0   both  Mid-range product
# 6          Soda        77              7     9.0   both  Mid-range product
# 7          Soda        77              7     9.0   both  Mid-range product
# 8          Soda        77              7     9.0   both  Mid-range product
# 9          Soda        77              7     9.0   both  Mid-range product
# 10         Soda        77              7     9.0   both  Mid-range product
# 11         Soda        77              7     9.0   both  Mid-range product
# 12         Soda        77              7     9.0   both  Mid-range product
# 13         Soda        77              7     9.0   both  Mid-range product
# 14         Soda        77              7     9.0   both  Mid-range product
# 15         Soda        77              7     9.0   both  Mid-range product
# 16         Soda        77              7     9.0   both  Mid-range product
# 17         Soda        77              7     9.0   both  Mid-range product
# 18         Soda        77              7     9.0   both  Mid-range product
# 19         Soda        77              7     9.0   both  Mid-range product
# 20         Soda        77              7     9.0   both  Mid-range product
# 21         Soda        77              7     9.0   both  Mid-range product
# 22         Soda        77              7     9.0   both  Mid-range product
# 23         Soda        77              7     9.0   both  Mid-range product
# 24         Soda        77              7     9.0   both  Mid-range product
# 25         Soda        77              7     9.0   both  Mid-range product
# 26         Soda        77              7     9.0   both  Mid-range product
# 27         Soda        77              7     9.0   both  Mid-range product
# 28         Soda        77              7     9.0   both  Mid-range product
# 29         Soda        77              7     9.0   both  Mid-range product
# 30         Soda        77              7     9.0   both  Mid-range product
# 31         Soda        77              7     9.0   both  Mid-range product
# 32         Soda        77              7     9.0   both  Mid-range product
# 33         Soda        77              7     9.0   both  Mid-range product
# 34         Soda        77              7     9.0   both  Mid-range product
# 35         Soda        77              7     9.0   both  Mid-range product
# 36         Soda        77              7     9.0   both  Mid-range product
# 37         Soda        77              7     9.0   both  Mid-range product
# 38         Soda        77              7     9.0   both  Mid-range product
# 39         Soda        77              7     9.0   both  Mid-range product
# 40         Soda        77              7     9.0   both  Mid-range product
# 41         Soda        77              7     9.0   both  Mid-range product
# 42         Soda        77              7     9.0   both  Mid-range product
# 43         Soda        77              7     9.0   both  Mid-range product
# 44         Soda        77              7     9.0   both  Mid-range product
# 45         Soda        77              7     9.0   both  Mid-range product
# 46         Soda        77              7     9.0   both  Mid-range product
# 47         Soda        77              7     9.0   both  Mid-range product
# 48         Soda        77              7     9.0   both  Mid-range product
# 49         Soda        77              7     9.0   both  Mid-range product
#
#      busiest_day  busiest_days busiest_period_of_day  max_order
# 0   Regular busy  Regular busy        Average orders         10
# 1   Regular busy    Least busy        Average orders         10
# 2   Regular busy    Least busy           Most orders         10
# 3     Least busy    Least busy        Average orders         10
# 4     Least busy    Least busy           Most orders         10
# 5   Regular busy  Regular busy        Average orders         10
# 6   Regular busy     Most busy           Most orders         10
# 7   Regular busy     Most busy           Most orders         10
# 8   Regular busy     Most busy           Most orders         10
# 9     Least busy    Least busy        Average orders         10
# 10  Regular busy     Most busy           Most orders         22
# 11  Regular busy  Regular busy           Most orders         22
# 12  Regular busy  Regular busy           Most orders         22
# 13  Regular busy     Most busy           Most orders         22
# 14  Regular busy     Most busy           Most orders         22
# 15  Regular busy  Regular busy           Most orders          9
# 16  Regular busy  Regular busy           Most orders          9
# 17    Least busy    Least busy           Most orders          9
# 18  Regular busy    Least busy           Most orders         33
# 19  Regular busy    Least busy        Average orders         20
# 20  Regular busy    Least busy           Most orders         20
# 21    Least busy    Least busy           Most orders         11
# 22    Least busy    Least busy           Most orders         11
# 23  Regular busy     Most busy           Most orders         27
# 24  Regular busy     Most busy           Most orders         27
# 25  Regular busy     Most busy           Most orders         27
# 26  Regular busy  Regular busy           Most orders         27
# 27  Regular busy  Regular busy        Average orders         27
# 28  Regular busy     Most busy           Most orders         27
# 29  Regular busy  Regular busy           Most orders         27
# 30  Regular busy  Regular busy           Most orders         27
# 31  Regular busy     Most busy           Most orders         27
# 32  Regular busy  Regular busy           Most orders         27
# 33  Regular busy  Regular busy           Most orders         27
# 34  Regular busy  Regular busy           Most orders         27
# 35  Regular busy    Least busy        Average orders         27
# 36  Regular busy  Regular busy           Most orders         27
# 37  Regular busy    Least busy           Most orders         24
# 38  Regular busy     Most busy           Most orders         24
# 39  Regular busy     Most busy           Most orders         24
# 40  Regular busy  Regular busy           Most orders         24
# 41  Regular busy    Least busy           Most orders         24
# 42  Regular busy    Least busy           Most orders         24
# 43  Regular busy  Regular busy           Most orders         24
# 44  Regular busy  Regular busy           Most orders         24
# 45  Regular busy     Most busy           Most orders         24
# 46  Regular busy     Most busy           Most orders         24
# 47  Regular busy  Regular busy           Most orders         24
# 48  Regular busy     Most busy           Most orders         24
# 49  Regular busy     Most busy           Most orders         24

# %%
ords_prods_merged.shape
# Out:
# (32399732, 19)

# %% [markdown]
# ### 03.6 loyalty_flag

# %%
# Create a new column 'loyalty_flag' to flag each user ID based on their "max_order" values
ords_prods_merged.loc[ords_prods_merged['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merged.loc[((ords_prods_merged['max_order'] > 10) & (ords_prods_merged['max_order'] <= 40)), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
# Check the output
ords_prods_merged[['user_id', 'max_order', 'loyalty_flag']].head(50)
# Out:
#     user_id  max_order      loyalty_flag
# 0         1         10      New customer
# 1         1         10      New customer
# 2         1         10      New customer
# 3         1         10      New customer
# 4         1         10      New customer
# 5         1         10      New customer
# 6         1         10      New customer
# 7         1         10      New customer
# 8         1         10      New customer
# 9         1         10      New customer
# 10       15         22  Regular customer
# 11       15         22  Regular customer
# 12       15         22  Regular customer
# 13       15         22  Regular customer
# 14       15         22  Regular customer
# 15       19          9      New customer
# 16       19          9      New customer
# 17       19          9      New customer
# 18       21         33  Regular customer
# 19       31         20  Regular customer
# 20       31         20  Regular customer
# 21       43         11  Regular customer
# 22       43         11  Regular customer
# 23       52         27  Regular customer
# 24       52         27  Regular customer
# 25       52         27  Regular customer
# 26       52         27  Regular customer
# 27       52         27  Regular customer
# 28       52         27  Regular customer
# 29       52         27  Regular customer
# 30       52         27  Regular customer
# 31       52         27  Regular customer
# 32       52         27  Regular customer
# 33       52         27  Regular customer
# 34       52         27  Regular customer
# 35       52         27  Regular customer
# 36       52         27  Regular customer
# 37       67         24  Regular customer
# 38       67         24  Regular customer
# 39       67         24  Regular customer
# 40       67         24  Regular customer
# 41       67         24  Regular customer
# 42       67         24  Regular customer
# 43       67         24  Regular customer
# 44       67         24  Regular customer
# 45       67         24  Regular customer
# 46       67         24  Regular customer
# 47       67         24  Regular customer
# 48       67         24  Regular customer
# 49       67         24  Regular customer

# %%
ords_prods_merged['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15874128
# Loyal customer      10282763
# New customer         6242841
# Name: loyalty_flag, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 20)

# %% [markdown]
# ### 03.7 avg_price

# %%
# Create a new column 'avg_price' to store the average price of products purchased for each user ID
ords_prods_merged['avg_price'] = ords_prods_merged.groupby('user_id')['prices'].transform(np.mean)

# %%
# Check the output
ords_prods_merged.head(50)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2968173       15            15                  1                  9
# 11   1870022       15            17                  2                 16
# 12   1911383       15            18                  2                 11
# 13   2715276       15            21                  1                  9
# 14    487368       15            22                  1                 10
# 15   2293453       19             2                  5                 14
# 16   1973799       19             5                  6                 12
# 17    532817       19             7                  4                 17
# 18   1573906       21            10                  3                 10
# 19   1593000       31            10                  3                  8
# 20   2231262       31            17                  3                 11
# 21   2580647       43             6                  4                 16
# 22   2187180       43             9                  4                 12
# 23   2497897       52             1                  1                  9
# 24   1318871       52             2                  1                 10
# 25   1261384       52             3                  1                 10
# 26    580568       52             5                  2                 10
# 27   2428073       52             7                  2                  7
# 28    342306       52             9                  1                 11
# 29   1520353       52            10                  2                 10
# 30   2542086       52            11                  2                  9
# 31    944694       52            12                  1                 16
# 32   1268191       52            15                  2                 11
# 33   1122089       52            17                  2                 10
# 34   1498922       52            18                  2                 10
# 35    180919       52            19                  3                  8
# 36   2695875       52            21                  5                 10
# 37   3205960       67             1                  3                 11
# 38    970922       67             2                  1                 15
# 39    596585       67             3                  1                 13
# 40   2037087       67             4                  2                  9
# 41   2474111       67             5                  3                 14
# 42   1568481       67             6                  3                 12
# 43   2048527       67             8                  2                 11
# 44   2389031       67             9                  2                 14
# 45   2378562       67            10                  1                 10
# 46   1515698       67            11                  1                 11
# 47   1928050       67            12                  2                 12
# 48   1949274       67            13                  1                 10
# 49    551869       67            14                  1                  9
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     7.0         196                  2          0
# 11                     8.0         196                  6          1
# 12                     7.0         196                  1          1
# 13                     7.0         196                  1          1
# 14                    14.0         196                  1          1
# 15                     6.0         196                  3          0
# 16                     8.0         196                 15          1
# 17                     6.0         196                  1          1
# 18                     6.0         196                  2          0
# 19                     7.0         196                 17          0
# 20                     8.0         196                 14          1
# 21                     4.0         196                  9          0
# 22                     3.0         196                  1          1
# 23                     NaN         196                  4          0
# 24                     7.0         196                  5          1
# 25                     7.0         196                  3          1
# 26                     8.0         196                  6          1
# 27                     8.0         196                  5          1
# 28                     7.0         196                  5          1
# 29                     8.0         196                  4          1
# 30                     7.0         196                  3          1
# 31                     6.0         196                  7          1
# 32                     8.0         196                  3          1
# 33                     6.0         196                  4          1
# 34                    14.0         196                  6          1
# 35                     8.0         196                  4          1
# 36                    30.0         196                  1          1
# 37                     NaN         196                  1          0
# 38                     5.0         196                  2          1
# 39                     7.0         196                  2          1
# 40                     8.0         196                  1          1
# 41                     8.0         196                  2          1
# 42                     7.0         196                  2          1
# 43                     7.0         196                  1          1
# 44                     7.0         196                  1          1
# 45                     6.0         196                  1          1
# 46                     7.0         196                  1          1
# 47                     8.0         196                  1          1
# 48                     6.0         196                  1          1
# 49                     7.0         196                  1          1
#
#    product_name  ...  department_id  prices  _merge        price_range  \
# 0          Soda  ...              7     9.0    both  Mid-range product
# 1          Soda  ...              7     9.0    both  Mid-range product
# 2          Soda  ...              7     9.0    both  Mid-range product
# 3          Soda  ...              7     9.0    both  Mid-range product
# 4          Soda  ...              7     9.0    both  Mid-range product
# 5          Soda  ...              7     9.0    both  Mid-range product
# 6          Soda  ...              7     9.0    both  Mid-range product
# 7          Soda  ...              7     9.0    both  Mid-range product
# 8          Soda  ...              7     9.0    both  Mid-range product
# 9          Soda  ...              7     9.0    both  Mid-range product
# 10         Soda  ...              7     9.0    both  Mid-range product
# 11         Soda  ...              7     9.0    both  Mid-range product
# 12         Soda  ...              7     9.0    both  Mid-range product
# 13         Soda  ...              7     9.0    both  Mid-range product
# 14         Soda  ...              7     9.0    both  Mid-range product
# 15         Soda  ...              7     9.0    both  Mid-range product
# 16         Soda  ...              7     9.0    both  Mid-range product
# 17         Soda  ...              7     9.0    both  Mid-range product
# 18         Soda  ...              7     9.0    both  Mid-range product
# 19         Soda  ...              7     9.0    both  Mid-range product
# 20         Soda  ...              7     9.0    both  Mid-range product
# 21         Soda  ...              7     9.0    both  Mid-range product
# 22         Soda  ...              7     9.0    both  Mid-range product
# 23         Soda  ...              7     9.0    both  Mid-range product
# 24         Soda  ...              7     9.0    both  Mid-range product
# 25         Soda  ...              7     9.0    both  Mid-range product
# 26         Soda  ...              7     9.0    both  Mid-range product
# 27         Soda  ...              7     9.0    both  Mid-range product
# 28         Soda  ...              7     9.0    both  Mid-range product
# 29         Soda  ...              7     9.0    both  Mid-range product
# 30         Soda  ...              7     9.0    both  Mid-range product
# 31         Soda  ...              7     9.0    both  Mid-range product
# 32         Soda  ...              7     9.0    both  Mid-range product
# 33         Soda  ...              7     9.0    both  Mid-range product
# 34         Soda  ...              7     9.0    both  Mid-range product
# 35         Soda  ...              7     9.0    both  Mid-range product
# 36         Soda  ...              7     9.0    both  Mid-range product
# 37         Soda  ...              7     9.0    both  Mid-range product
# 38         Soda  ...              7     9.0    both  Mid-range product
# 39         Soda  ...              7     9.0    both  Mid-range product
# 40         Soda  ...              7     9.0    both  Mid-range product
# 41         Soda  ...              7     9.0    both  Mid-range product
# 42         Soda  ...              7     9.0    both  Mid-range product
# 43         Soda  ...              7     9.0    both  Mid-range product
# 44         Soda  ...              7     9.0    both  Mid-range product
# 45         Soda  ...              7     9.0    both  Mid-range product
# 46         Soda  ...              7     9.0    both  Mid-range product
# 47         Soda  ...              7     9.0    both  Mid-range product
# 48         Soda  ...              7     9.0    both  Mid-range product
# 49         Soda  ...              7     9.0    both  Mid-range product
#
#      busiest_day  busiest_days busiest_period_of_day max_order  \
# 0   Regular busy  Regular busy        Average orders        10
# 1   Regular busy    Least busy        Average orders        10
# 2   Regular busy    Least busy           Most orders        10
# 3     Least busy    Least busy        Average orders        10
# 4     Least busy    Least busy           Most orders        10
# 5   Regular busy  Regular busy        Average orders        10
# 6   Regular busy     Most busy           Most orders        10
# 7   Regular busy     Most busy           Most orders        10
# 8   Regular busy     Most busy           Most orders        10
# 9     Least busy    Least busy        Average orders        10
# 10  Regular busy     Most busy           Most orders        22
# 11  Regular busy  Regular busy           Most orders        22
# 12  Regular busy  Regular busy           Most orders        22
# 13  Regular busy     Most busy           Most orders        22
# 14  Regular busy     Most busy           Most orders        22
# 15  Regular busy  Regular busy           Most orders         9
# 16  Regular busy  Regular busy           Most orders         9
# 17    Least busy    Least busy           Most orders         9
# 18  Regular busy    Least busy           Most orders        33
# 19  Regular busy    Least busy        Average orders        20
# 20  Regular busy    Least busy           Most orders        20
# 21    Least busy    Least busy           Most orders        11
# 22    Least busy    Least busy           Most orders        11
# 23  Regular busy     Most busy           Most orders        27
# 24  Regular busy     Most busy           Most orders        27
# 25  Regular busy     Most busy           Most orders        27
# 26  Regular busy  Regular busy           Most orders        27
# 27  Regular busy  Regular busy        Average orders        27
# 28  Regular busy     Most busy           Most orders        27
# 29  Regular busy  Regular busy           Most orders        27
# 30  Regular busy  Regular busy           Most orders        27
# 31  Regular busy     Most busy           Most orders        27
# 32  Regular busy  Regular busy           Most orders        27
# 33  Regular busy  Regular busy           Most orders        27
# 34  Regular busy  Regular busy           Most orders        27
# 35  Regular busy    Least busy        Average orders        27
# 36  Regular busy  Regular busy           Most orders        27
# 37  Regular busy    Least busy           Most orders        24
# 38  Regular busy     Most busy           Most orders        24
# 39  Regular busy     Most busy           Most orders        24
# 40  Regular busy  Regular busy           Most orders        24
# 41  Regular busy    Least busy           Most orders        24
# 42  Regular busy    Least busy           Most orders        24
# 43  Regular busy  Regular busy           Most orders        24
# 44  Regular busy  Regular busy           Most orders        24
# 45  Regular busy     Most busy           Most orders        24
# 46  Regular busy     Most busy           Most orders        24
# 47  Regular busy  Regular busy           Most orders        24
# 48  Regular busy     Most busy           Most orders        24
# 49  Regular busy     Most busy           Most orders        24
#
#         loyalty_flag avg_price
# 0       New customer  6.367797
# 1       New customer  6.367797
# 2       New customer  6.367797
# 3       New customer  6.367797
# 4       New customer  6.367797
# 5       New customer  6.367797
# 6       New customer  6.367797
# 7       New customer  6.367797
# 8       New customer  6.367797
# 9       New customer  6.367797
# 10  Regular customer  3.980556
# 11  Regular customer  3.980556
# 12  Regular customer  3.980556
# 13  Regular customer  3.980556
# 14  Regular customer  3.980556
# 15      New customer  8.372059
# 16      New customer  8.372059
# 17      New customer  8.372059
# 18  Regular customer  7.012683
# 19  Regular customer  8.137793
# 20  Regular customer  8.137793
# 21  Regular customer  7.444898
# 22  Regular customer  7.444898
# 23  Regular customer  6.356287
# 24  Regular customer  6.356287
# 25  Regular customer  6.356287
# 26  Regular customer  6.356287
# 27  Regular customer  6.356287
# 28  Regular customer  6.356287
# 29  Regular customer  6.356287
# 30  Regular customer  6.356287
# 31  Regular customer  6.356287
# 32  Regular customer  6.356287
# 33  Regular customer  6.356287
# 34  Regular customer  6.356287
# 35  Regular customer  6.356287
# 36  Regular customer  6.356287
# 37  Regular customer  7.656790
# 38  Regular customer  7.656790
# 39  Regular customer  7.656790
# 40  Regular customer  7.656790
# 41  Regular customer  7.656790
# 42  Regular customer  7.656790
# 43  Regular customer  7.656790
# 44  Regular customer  7.656790
# 45  Regular customer  7.656790
# 46  Regular customer  7.656790
# 47  Regular customer  7.656790
# 48  Regular customer  7.656790
# 49  Regular customer  7.656790
#
# [50 rows x 21 columns]

# %%
ords_prods_merged.shape
# Out:
# (32399732, 21)

# %% [markdown]
# ### 03.8 spender_flag

# %%
# Create a new column 'spender_flag' to flag each user ID based on their "avg_price" values
ords_prods_merged.loc[ords_prods_merged['avg_price'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merged.loc[ords_prods_merged['avg_price'] >= 10, 'spender_flag'] = 'High spender'

# %%
# Check the output
ords_prods_merged[['user_id', 'avg_price', 'spender_flag']].head(50)
# Out:
#     user_id  avg_price spender_flag
# 0         1   6.367797  Low spender
# 1         1   6.367797  Low spender
# 2         1   6.367797  Low spender
# 3         1   6.367797  Low spender
# 4         1   6.367797  Low spender
# 5         1   6.367797  Low spender
# 6         1   6.367797  Low spender
# 7         1   6.367797  Low spender
# 8         1   6.367797  Low spender
# 9         1   6.367797  Low spender
# 10       15   3.980556  Low spender
# 11       15   3.980556  Low spender
# 12       15   3.980556  Low spender
# 13       15   3.980556  Low spender
# 14       15   3.980556  Low spender
# 15       19   8.372059  Low spender
# 16       19   8.372059  Low spender
# 17       19   8.372059  Low spender
# 18       21   7.012683  Low spender
# 19       31   8.137793  Low spender
# 20       31   8.137793  Low spender
# 21       43   7.444898  Low spender
# 22       43   7.444898  Low spender
# 23       52   6.356287  Low spender
# 24       52   6.356287  Low spender
# 25       52   6.356287  Low spender
# 26       52   6.356287  Low spender
# 27       52   6.356287  Low spender
# 28       52   6.356287  Low spender
# 29       52   6.356287  Low spender
# 30       52   6.356287  Low spender
# 31       52   6.356287  Low spender
# 32       52   6.356287  Low spender
# 33       52   6.356287  Low spender
# 34       52   6.356287  Low spender
# 35       52   6.356287  Low spender
# 36       52   6.356287  Low spender
# 37       67   7.656790  Low spender
# 38       67   7.656790  Low spender
# 39       67   7.656790  Low spender
# 40       67   7.656790  Low spender
# 41       67   7.656790  Low spender
# 42       67   7.656790  Low spender
# 43       67   7.656790  Low spender
# 44       67   7.656790  Low spender
# 45       67   7.656790  Low spender
# 46       67   7.656790  Low spender
# 47       67   7.656790  Low spender
# 48       67   7.656790  Low spender
# 49       67   7.656790  Low spender

# %%
ords_prods_merged['spender_flag'].value_counts(dropna = False)
# Out:
# Low spender     32280013
# High spender      119719
# Name: spender_flag, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 22)

# %% [markdown]
# ### 03.9 median_order_interval

# %%
# Create a new column 'median_order_interval' to store the median of 'days_since_prior_order' values for each user ID
ords_prods_merged['median_order_interval'] = ords_prods_merged.groupby('user_id')['days_since_prior_order'].transform(np.median)

# %%
# Check the output
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  ...  _merge        price_range   busiest_day  busiest_days  \
# 0         Soda  ...    both  Mid-range product  Regular busy  Regular busy
# 1         Soda  ...    both  Mid-range product  Regular busy    Least busy
# 2         Soda  ...    both  Mid-range product  Regular busy    Least busy
# 3         Soda  ...    both  Mid-range product    Least busy    Least busy
# 4         Soda  ...    both  Mid-range product    Least busy    Least busy
#
#   busiest_period_of_day max_order  loyalty_flag avg_price  spender_flag  \
# 0        Average orders        10  New customer  6.367797   Low spender
# 1        Average orders        10  New customer  6.367797   Low spender
# 2           Most orders        10  New customer  6.367797   Low spender
# 3        Average orders        10  New customer  6.367797   Low spender
# 4           Most orders        10  New customer  6.367797   Low spender
#
#   median_order_interval
# 0                  20.5
# 1                  20.5
# 2                  20.5
# 3                  20.5
# 4                  20.5
#
# [5 rows x 23 columns]

# %%
ords_prods_merged.shape
# Out:
# (32399732, 23)

# %% [markdown]
# ### 03.10 order_frequency_flag

# %%
# Create a new column 'order_frequency_flag' to flag each user ID based on their 'median_order_interval' values
ords_prods_merged.loc[ords_prods_merged['median_order_interval'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merged.loc[((ords_prods_merged['median_order_interval'] > 10) & (ords_prods_merged['median_order_interval'] <= 20)), 'order_frequency_flag'] = 'Regular customer'

# %%
ords_prods_merged.loc[ords_prods_merged['median_order_interval'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
# Check the output
ords_prods_merged[['user_id', 'median_order_interval', 'order_frequency_flag']].head(50)
# Out:
#     user_id  median_order_interval   order_frequency_flag
# 0         1                   20.5  Non-frequent customer
# 1         1                   20.5  Non-frequent customer
# 2         1                   20.5  Non-frequent customer
# 3         1                   20.5  Non-frequent customer
# 4         1                   20.5  Non-frequent customer
# 5         1                   20.5  Non-frequent customer
# 6         1                   20.5  Non-frequent customer
# 7         1                   20.5  Non-frequent customer
# 8         1                   20.5  Non-frequent customer
# 9         1                   20.5  Non-frequent customer
# 10       15                   10.0      Frequent customer
# 11       15                   10.0      Frequent customer
# 12       15                   10.0      Frequent customer
# 13       15                   10.0      Frequent customer
# 14       15                   10.0      Frequent customer
# 15       19                    6.0      Frequent customer
# 16       19                    6.0      Frequent customer
# 17       19                    6.0      Frequent customer
# 18       21                    7.5      Frequent customer
# 19       31                    6.0      Frequent customer
# 20       31                    6.0      Frequent customer
# 21       43                   10.0      Frequent customer
# 22       43                   10.0      Frequent customer
# 23       52                    8.0      Frequent customer
# 24       52                    8.0      Frequent customer
# 25       52                    8.0      Frequent customer
# 26       52                    8.0      Frequent customer
# 27       52                    8.0      Frequent customer
# 28       52                    8.0      Frequent customer
# 29       52                    8.0      Frequent customer
# 30       52                    8.0      Frequent customer
# 31       52                    8.0      Frequent customer
# 32       52                    8.0      Frequent customer
# 33       52                    8.0      Frequent customer
# 34       52                    8.0      Frequent customer
# 35       52                    8.0      Frequent customer
# 36       52                    8.0      Frequent customer
# 37       67                    7.0      Frequent customer
# 38       67                    7.0      Frequent customer
# 39       67                    7.0      Frequent customer
# 40       67                    7.0      Frequent customer
# 41       67                    7.0      Frequent customer
# 42       67                    7.0      Frequent customer
# 43       67                    7.0      Frequent customer
# 44       67                    7.0      Frequent customer
# 45       67                    7.0      Frequent customer
# 46       67                    7.0      Frequent customer
# 47       67                    7.0      Frequent customer
# 48       67                    7.0      Frequent customer
# 49       67                    7.0      Frequent customer

# %%
ords_prods_merged['order_frequency_flag'].value_counts(dropna = False)
# Out:
# Frequent customer        21556644
# Regular customer          7207340
# Non-frequent customer     3635743
# NaN                             5
# Name: order_frequency_flag, dtype: int64

# %%
ords_prods_merged.shape
# Out:
# (32399732, 24)

# %% [markdown]
# #### Why are there mising values in 'order_frequency_flag' column?
# Remember that users with maximum order of 1 do not have any value in 'days_since_prior_order' column, as well as this 'order_frequency_flag' column that is derived from 'days_since_prior_order' column.

# %%
# Users that have missing 'order_frequency_flag' come with maximum order of 1
ords_prods_merged.loc[ords_prods_merged['order_frequency_flag'].isnull() == True, ['user_id', 'order_number', 'max_order', 'days_since_prior_order', 'median_order_interval', 'order_frequency_flag']]
# Out:
#           user_id  order_number  max_order  days_since_prior_order  \
# 13641263   159838             1          1                     NaN
# 17247561   159838             1          1                     NaN
# 17618338   159838             1          1                     NaN
# 24134164   159838             1          1                     NaN
# 25875573   159838             1          1                     NaN
#
#           median_order_interval order_frequency_flag
# 13641263                    NaN                  NaN
# 17247561                    NaN                  NaN
# 17618338                    NaN                  NaN
# 24134164                    NaN                  NaN
# 25875573                    NaN                  NaN

# %% [markdown]
# # 04. Export Data

# %%
# Take a final look of 'ords_prods_merged' dataframe
ords_prods_merged
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32399727   1320836   202557            17                  2
# 32399728     31526   202557            18                  5
# 32399729    758936   203436             1                  2
# 32399730   2745165   203436             2                  3
# 32399731   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# 2                        12                    21.0         196
# 3                         7                    29.0         196
# 4                        15                    28.0         196
# ...                     ...                     ...         ...
# 32399727                 15                     1.0       43553
# 32399728                 11                     3.0       43553
# 32399729                  7                     NaN       42338
# 32399730                  5                    15.0       42338
# 32399731                 14                     NaN       28818
#
#           add_to_cart_order  reordered                   product_name  ...  \
# 0                         1          0                           Soda  ...
# 1                         1          1                           Soda  ...
# 2                         1          1                           Soda  ...
# 3                         1          1                           Soda  ...
# 4                         1          1                           Soda  ...
# ...                     ...        ...                            ...  ...
# 32399727                  2          1            Orange Energy Shots  ...
# 32399728                  2          1            Orange Energy Shots  ...
# 32399729                  4          0          Zucchini Chips, Pesto  ...
# 32399730                 16          1          Zucchini Chips, Pesto  ...
# 32399731                  8          0  Hot Oatmeal Multigrain Raisin  ...
#
#                 price_range   busiest_day  busiest_days busiest_period_of_day  \
# 0         Mid-range product  Regular busy  Regular busy        Average orders
# 1         Mid-range product  Regular busy    Least busy        Average orders
# 2         Mid-range product  Regular busy    Least busy           Most orders
# 3         Mid-range product    Least busy    Least busy        Average orders
# 4         Mid-range product    Least busy    Least busy           Most orders
# ...                     ...           ...           ...                   ...
# 32399727  Low-range product  Regular busy  Regular busy           Most orders
# 32399728  Low-range product  Regular busy  Regular busy           Most orders
# 32399729  Mid-range product  Regular busy  Regular busy        Average orders
# 32399730  Mid-range product  Regular busy    Least busy         Fewest orders
# 32399731  Mid-range product    Least busy    Least busy           Most orders
#
#          max_order      loyalty_flag avg_price spender_flag  \
# 0               10      New customer  6.367797  Low spender
# 1               10      New customer  6.367797  Low spender
# 2               10      New customer  6.367797  Low spender
# 3               10      New customer  6.367797  Low spender
# 4               10      New customer  6.367797  Low spender
# ...            ...               ...       ...          ...
# 32399727        31  Regular customer  6.905655  Low spender
# 32399728        31  Regular customer  6.905655  Low spender
# 32399729         3      New customer  7.631579  Low spender
# 32399730         3      New customer  7.631579  Low spender
# 32399731        16  Regular customer  7.684746  Low spender
#
#           median_order_interval   order_frequency_flag
# 0                          20.5  Non-frequent customer
# 1                          20.5  Non-frequent customer
# 2                          20.5  Non-frequent customer
# 3                          20.5  Non-frequent customer
# 4                          20.5  Non-frequent customer
# ...                         ...                    ...
# 32399727                    8.0      Frequent customer
# 32399728                    8.0      Frequent customer
# 32399729                   15.0       Regular customer
# 32399730                   15.0       Regular customer
# 32399731                   13.0       Regular customer
#
# [32399732 rows x 24 columns]

# %%
# Export 'ords_prods_merged' dataframe to 'Prepared Data' folder in pickle format
ords_prods_merged.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_flagged.pkl'))
