# %% [markdown]
# # Table of Content
# 01. Import Libraries
# 02. Import Data
# 03. Change Data Types to Save Memory
# 04. Merge Data
# 05. Export Data

# %% [markdown]
# # 01. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Adjust the setting to view all columns in this notebook
pd.options.display.max_columns = None

# %% [markdown]
# # 02. Import Data

# %%
# Define the main project folder path
path = r'C:\Users\saich\Desktop\CareerFoundry\Data Immersion\Achievement 4 Python Fundamentals for Data Analysts\04-2023 Instacart Basket Analysis (github)'

# %%
# Import 'orders_products_merged_flagged' data set from 'Prepared Data' folder
ords_prods_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_flagged.pkl'))

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices _merge        price_range  \
# 0         Soda        77              7     9.0   both  Mid-range product
# 1         Soda        77              7     9.0   both  Mid-range product
# 2         Soda        77              7     9.0   both  Mid-range product
# 3         Soda        77              7     9.0   both  Mid-range product
# 4         Soda        77              7     9.0   both  Mid-range product
#
#     busiest_day  busiest_days busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regular busy  Regular busy        Average orders         10  New customer
# 1  Regular busy    Least busy        Average orders         10  New customer
# 2  Regular busy    Least busy           Most orders         10  New customer
# 3    Least busy    Least busy        Average orders         10  New customer
# 4    Least busy    Least busy           Most orders         10  New customer
#
#    avg_price spender_flag  median_order_interval   order_frequency_flag
# 0   6.367797  Low spender                   20.5  Non-frequent customer
# 1   6.367797  Low spender                   20.5  Non-frequent customer
# 2   6.367797  Low spender                   20.5  Non-frequent customer
# 3   6.367797  Low spender                   20.5  Non-frequent customer
# 4   6.367797  Low spender                   20.5  Non-frequent customer

# %%
ords_prods_merged.shape
# Out:
# (32399732, 24)

# %%
# Import 'customers_checked' data set from 'Prepared Data' folder
cust = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'customers_checked.csv'), index_col = 0)

# %%
cust.head()
# Out:
#    user_id  gender       state  age date_joined  dependant_counts  \
# 0    26711  Female    Missouri   48    1/1/2017                 3
# 1    33890  Female  New Mexico   36    1/1/2017                 0
# 2    65803    Male       Idaho   35    1/1/2017                 2
# 3   125935  Female        Iowa   40    1/1/2017                 0
# 4   130797  Female    Maryland   26    1/1/2017                 1
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
cust.shape
# Out:
# (206209, 8)

# %% [markdown]
# # 03. Change Data Types to Save Memory

# %%
# Check the memory usage and column data types of 'ords_prods_merged' dataframe
ords_prods_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32399732 entries, 0 to 32399731
# Data columns (total 24 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int8
#  3   order_day_of_week       int8
#  4   order_hour_of_day       int8
#  5   days_since_prior_order  float16
#  6   product_id              int32
#  7   add_to_cart_order       int32
#  8   reordered               int8
#  9   product_name            object
#  10  aisle_id                int8
#  11  department_id           int8
#  12  prices                  float32
#  13  _merge                  category
#  14  price_range             object
#  15  busiest_day             object
#  16  busiest_days            object
#  17  busiest_period_of_day   object
#  18  max_order               int8
#  19  loyalty_flag            object
#  20  avg_price               float32
#  21  spender_flag            object
#  22  median_order_interval   float16
#  23  order_frequency_flag    object
# dtypes: category(1), float16(2), float32(2), int32(4), int8(7), object(8)
# memory usage: 3.3+ GB

# %%
# Check the memory usage and column data types of 'cust' dataframe
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206209 entries, 0 to 206208
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           206209 non-null  int64
#  1   gender            206209 non-null  object
#  2   state             206209 non-null  object
#  3   age               206209 non-null  int64
#  4   date_joined       206209 non-null  object
#  5   dependant_counts  206209 non-null  int64
#  6   family_status     206209 non-null  object
#  7   income            206209 non-null  int64
# dtypes: int64(4), object(4)
# memory usage: 14.2+ MB

# %%
# Change the data types 'cust' dataframe
cust['user_id'] = cust['user_id'].astype('int32')
cust['age'] = cust['age'].astype('int8')
cust['dependant_counts'] = cust['dependant_counts'].astype('int8')
cust['income'] = cust['income'].astype('int32')

# %%
# Check the memory usage and column data types of 'cust' dataframe after data types changes
cust.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 206209 entries, 0 to 206208
# Data columns (total 8 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   user_id           206209 non-null  int32
#  1   gender            206209 non-null  object
#  2   state             206209 non-null  object
#  3   age               206209 non-null  int8
#  4   date_joined       206209 non-null  object
#  5   dependant_counts  206209 non-null  int8
#  6   family_status     206209 non-null  object
#  7   income            206209 non-null  int32
# dtypes: int32(2), int8(2), object(4)
# memory usage: 9.8+ MB

# %% [markdown]
# # 04. Merge Data

# %%
# Before merging data, drop the '_merge' column in 'ords_prods_merged' dataframe, else will get an error
ords_prods_merged.drop(columns = ['_merge'], inplace = True)

# %%
ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#   product_name  aisle_id  department_id  prices        price_range  \
# 0         Soda        77              7     9.0  Mid-range product
# 1         Soda        77              7     9.0  Mid-range product
# 2         Soda        77              7     9.0  Mid-range product
# 3         Soda        77              7     9.0  Mid-range product
# 4         Soda        77              7     9.0  Mid-range product
#
#     busiest_day  busiest_days busiest_period_of_day  max_order  loyalty_flag  \
# 0  Regular busy  Regular busy        Average orders         10  New customer
# 1  Regular busy    Least busy        Average orders         10  New customer
# 2  Regular busy    Least busy           Most orders         10  New customer
# 3    Least busy    Least busy        Average orders         10  New customer
# 4    Least busy    Least busy           Most orders         10  New customer
#
#    avg_price spender_flag  median_order_interval   order_frequency_flag
# 0   6.367797  Low spender                   20.5  Non-frequent customer
# 1   6.367797  Low spender                   20.5  Non-frequent customer
# 2   6.367797  Low spender                   20.5  Non-frequent customer
# 3   6.367797  Low spender                   20.5  Non-frequent customer
# 4   6.367797  Low spender                   20.5  Non-frequent customer

# %%
# Merge 'ords_prods_merged' dataframe with 'cust' dataframe using 'user_id' as the key column
ords_prods_all = ords_prods_merged.merge(cust, on = ['user_id'], indicator = True)

# %%
# Check the output
ords_prods_all.head(20)
# Out:
#     order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                  2                  8
# 1    2398795        1             2                  3                  7
# 2     473747        1             3                  3                 12
# 3    2254736        1             4                  4                  7
# 4     431534        1             5                  4                 15
# 5    3367565        1             6                  2                  7
# 6     550135        1             7                  1                  9
# 7    3108588        1             8                  1                 14
# 8    2295261        1             9                  1                 16
# 9    2550362        1            10                  4                  8
# 10   2539329        1             1                  2                  8
# 11   2539329        1             1                  2                  8
# 12   2398795        1             2                  3                  7
# 13    473747        1             3                  3                 12
# 14   2254736        1             4                  4                  7
# 15    431534        1             5                  4                 15
# 16   3367565        1             6                  2                  7
# 17    550135        1             7                  1                  9
# 18   3108588        1             8                  1                 14
# 19   2295261        1             9                  1                 16
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                     15.0         196                  1          1
# 2                     21.0         196                  1          1
# 3                     29.0         196                  1          1
# 4                     28.0         196                  1          1
# 5                     19.0         196                  1          1
# 6                     20.0         196                  1          1
# 7                     14.0         196                  2          1
# 8                      0.0         196                  4          1
# 9                     30.0         196                  1          1
# 10                     NaN       14084                  2          0
# 11                     NaN       12427                  3          0
# 12                    15.0       12427                  3          1
# 13                    21.0       12427                  2          1
# 14                    29.0       12427                  2          1
# 15                    28.0       12427                  2          1
# 16                    19.0       12427                  2          1
# 17                    20.0       12427                  3          1
# 18                    14.0       12427                  1          1
# 19                     0.0       12427                  6          1
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda        77              7     9.0
# 1                                      Soda        77              7     9.0
# 2                                      Soda        77              7     9.0
# 3                                      Soda        77              7     9.0
# 4                                      Soda        77              7     9.0
# 5                                      Soda        77              7     9.0
# 6                                      Soda        77              7     9.0
# 7                                      Soda        77              7     9.0
# 8                                      Soda        77              7     9.0
# 9                                      Soda        77              7     9.0
# 10  Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 11                      Original Beef Jerky        23             19     4.4
# 12                      Original Beef Jerky        23             19     4.4
# 13                      Original Beef Jerky        23             19     4.4
# 14                      Original Beef Jerky        23             19     4.4
# 15                      Original Beef Jerky        23             19     4.4
# 16                      Original Beef Jerky        23             19     4.4
# 17                      Original Beef Jerky        23             19     4.4
# 18                      Original Beef Jerky        23             19     4.4
# 19                      Original Beef Jerky        23             19     4.4
#
#           price_range   busiest_day  busiest_days busiest_period_of_day  \
# 0   Mid-range product  Regular busy  Regular busy        Average orders
# 1   Mid-range product  Regular busy    Least busy        Average orders
# 2   Mid-range product  Regular busy    Least busy           Most orders
# 3   Mid-range product    Least busy    Least busy        Average orders
# 4   Mid-range product    Least busy    Least busy           Most orders
# 5   Mid-range product  Regular busy  Regular busy        Average orders
# 6   Mid-range product  Regular busy     Most busy           Most orders
# 7   Mid-range product  Regular busy     Most busy           Most orders
# 8   Mid-range product  Regular busy     Most busy           Most orders
# 9   Mid-range product    Least busy    Least busy        Average orders
# 10  Mid-range product  Regular busy  Regular busy        Average orders
# 11  Low-range product  Regular busy  Regular busy        Average orders
# 12  Low-range product  Regular busy    Least busy        Average orders
# 13  Low-range product  Regular busy    Least busy           Most orders
# 14  Low-range product    Least busy    Least busy        Average orders
# 15  Low-range product    Least busy    Least busy           Most orders
# 16  Low-range product  Regular busy  Regular busy        Average orders
# 17  Low-range product  Regular busy     Most busy           Most orders
# 18  Low-range product  Regular busy     Most busy           Most orders
# 19  Low-range product  Regular busy     Most busy           Most orders
#
#     max_order  loyalty_flag  avg_price spender_flag  median_order_interval  \
# 0          10  New customer   6.367797  Low spender                   20.5
# 1          10  New customer   6.367797  Low spender                   20.5
# 2          10  New customer   6.367797  Low spender                   20.5
# 3          10  New customer   6.367797  Low spender                   20.5
# 4          10  New customer   6.367797  Low spender                   20.5
# 5          10  New customer   6.367797  Low spender                   20.5
# 6          10  New customer   6.367797  Low spender                   20.5
# 7          10  New customer   6.367797  Low spender                   20.5
# 8          10  New customer   6.367797  Low spender                   20.5
# 9          10  New customer   6.367797  Low spender                   20.5
# 10         10  New customer   6.367797  Low spender                   20.5
# 11         10  New customer   6.367797  Low spender                   20.5
# 12         10  New customer   6.367797  Low spender                   20.5
# 13         10  New customer   6.367797  Low spender                   20.5
# 14         10  New customer   6.367797  Low spender                   20.5
# 15         10  New customer   6.367797  Low spender                   20.5
# 16         10  New customer   6.367797  Low spender                   20.5
# 17         10  New customer   6.367797  Low spender                   20.5
# 18         10  New customer   6.367797  Low spender                   20.5
# 19         10  New customer   6.367797  Low spender                   20.5
#
#      order_frequency_flag  gender    state  age date_joined  dependant_counts  \
# 0   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 1   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 2   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 3   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 4   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 5   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 6   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 7   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 8   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 9   Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 10  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 11  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 12  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 13  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 14  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 15  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 16  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 17  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 18  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
# 19  Non-frequent customer  Female  Alabama   31   2/17/2019                 3
#
#    family_status  income _merge
# 0        married   40423   both
# 1        married   40423   both
# 2        married   40423   both
# 3        married   40423   both
# 4        married   40423   both
# 5        married   40423   both
# 6        married   40423   both
# 7        married   40423   both
# 8        married   40423   both
# 9        married   40423   both
# 10       married   40423   both
# 11       married   40423   both
# 12       married   40423   both
# 13       married   40423   both
# 14       married   40423   both
# 15       married   40423   both
# 16       married   40423   both
# 17       married   40423   both
# 18       married   40423   both
# 19       married   40423   both

# %%
ords_prods_all['_merge'].value_counts(dropna = False)
# Out:
# both          32399732
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# From the frequency check above, there are only entries that have a value of “both,” leading you to think that your key column, “order_id” exists completely in both dataframes. However, this conclusion is wrong. This is because you chose the default option of inner join in this merge. This means that the resulting table will only contain observations found in both dataframes. As such, the merge flag here will only show entries that have a value of “both.”

# %%
# To check whether it is a full match, use outer join
# Merge 'ords_prods_merged' dataframe with 'cust' dataframe using 'user_id' as the key column and outer join
ords_prods_all_outer = ords_prods_merged.merge(cust, on = 'user_id', how = 'outer', indicator = True)

# %%
ords_prods_all_outer['_merge'].value_counts(dropna = False)
# Out:
# both          32399732
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# The actual merge rate of both dataframes is 100%.

# %% [markdown]
# # 05. Export Data

# %%
# Dimension check for 'ords_prods_all' dataframe after data merging
ords_prods_all.shape
# Out:
# (32399732, 31)

# %%
# Export 'ords_prods_all' dataframe to 'Prepared Data' folder in pickle format
ords_prods_all.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_all.pkl'))
