# %% [markdown]
# # Table of Content
# 01. Import Libraries
# 02. Import Data
# 03. Transposing Data
# 04. Export Data
# 05. Import the Transposed Data for Verification

# %% [markdown]
# # 01. Import Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02. Import Data

# %%
# Define the main project folder path
path = r'C:\Users\saich\Desktop\CareerFoundry\Data Immersion\Achievement 4 Python Fundamentals for Data Analysts\04-2023 Instacart Basket Analysis (github)'

# %%
# Import 'departments' data set from 'Original Data' folder
dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
dep.shape
# Out:
# (1, 22)

# %% [markdown]
# # 03. Transposing Data

# %%
# 1. Transpose the 'dep' dataframe.
dep_t = dep.T

# %%
dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# The column title above is not right. 
# 2. Create a new header for the new transposed data later.
new_header = dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# 3. Save a new version of the transposed data which include only the actual content (start from row 1, don't include row 0).
dep_t_new = dep_t.iloc[1:]

# %%
dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# The new version of transposed data doesn't have a column header. Let's add them. 
# 4. Assign the new header we created in step 2 to this new version of transposed data. 
dep_t_new.columns = new_header

# %%
dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
# 5. Reset the index of the new transposed data. This will create a new column called 'index'.
dep_t_new = dep_t_new.reset_index()

# %%
dep_t_new
# Out:
# department_id index       department
# 0                 1           frozen
# 1                 2            other
# 2                 3           bakery
# 3                 4          produce
# 4                 5          alcohol
# 5                 6    international
# 6                 7        beverages
# 7                 8             pets
# 8                 9  dry goods pasta
# 9                10             bulk
# 10               11    personal care
# 11               12     meat seafood
# 12               13           pantry
# 13               14        breakfast
# 14               15     canned goods
# 15               16       dairy eggs
# 16               17        household
# 17               18           babies
# 18               19           snacks
# 19               20             deli
# 20               21          missing

# %%
# 6. Change the 'index' column name to 'department_id'. 
# Don't worry if you see two identical column names here. It will disappear when we import this data back again. 
dep_t_new.rename(columns = {'index' : 'department_id'}, inplace = True)

# %%
dep_t_new
# Out:
# department_id department_id       department
# 0                         1           frozen
# 1                         2            other
# 2                         3           bakery
# 3                         4          produce
# 4                         5          alcohol
# 5                         6    international
# 6                         7        beverages
# 7                         8             pets
# 8                         9  dry goods pasta
# 9                        10             bulk
# 10                       11    personal care
# 11                       12     meat seafood
# 12                       13           pantry
# 13                       14        breakfast
# 14                       15     canned goods
# 15                       16       dairy eggs
# 16                       17        household
# 17                       18           babies
# 18                       19           snacks
# 19                       20             deli
# ...

# %% [markdown]
# # 04. Export Data

# %%
# Export 'dep_t_new' to 'Prepared Data' folder in csv format
dep_t_new.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'))

# %% [markdown]
# # 05. Import the Transposed Data for Verification

# %%
# Import the 'departments_wrangled' data set for verification
dep_t_import = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'departments_wrangled.csv'), index_col = 0)

# %%
dep_t_import
# Out:
#     department_id       department
# 0               1           frozen
# 1               2            other
# 2               3           bakery
# 3               4          produce
# 4               5          alcohol
# 5               6    international
# 6               7        beverages
# 7               8             pets
# 8               9  dry goods pasta
# 9              10             bulk
# 10             11    personal care
# 11             12     meat seafood
# 12             13           pantry
# 13             14        breakfast
# 14             15     canned goods
# 15             16       dairy eggs
# 16             17        household
# 17             18           babies
# 18             19           snacks
# 19             20             deli
# 20             21          missing

# %% [markdown]
# The 'departments_wrangled' data set looks good.
